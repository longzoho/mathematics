# %%
from IPython.display import display, Math
from sympy import Matrix, latex, symbols, Derivative, solve, limit, integrate, sqrt, expand, factor, oo, root, Rational, \
    ln, expand_log, together, apart, trigsimp, sin, cos, tan, cot, sec, csc, simplify, exp, E, diff, tan, Integral, \
    Limit
from sympy.plotting import plot3d
# solve: giải phương trình
# Derivative: đạo hàm
# Matrix: ma trận
# latex: hiển thị công thức toán học
# display: hiển thị kết quả
# symbols: khai báo biến
# limit: giới hạn
# integrate: tích phân
# expand: triển khai (phân phối)
# factor: phân tích (kết hợp)
# oo: vô cùng
# together: tổng hợp
# integrate: tích phân
# diff: đạo hàm
# root: căn 
# e: E
# f.subs(x, 0): thay x = 0 vào f
# ##.function: hàm số (của đạo hàm hoặc tích phân)

# %%
x, y = symbols('x y')

# %%
f = y**3-12*x*y+6*x**2-36*x+7
display(Math(latex(f)))
# Out:
# $\displaystyle 6 x^{2} - 12 x y - 36 x + y^{3} + 7$

# %%
# Tính đạo hàm riêng
f_x = f.diff(x)
f_y = f.diff(y)

# %%
display(Math(latex(f_x)))
display(Math(latex(f_y)))
# Out:
# $\displaystyle 12 x - 12 y - 36$
# $\displaystyle - 12 x + 3 y^{2}$

# %%
# Tìm điểm tới hạn
critical_points = solve([f_x, f_y], [x, y])
display(critical_points)
# Out:
# [(1, -2), (9, 6)]

# %%
plot3d(f, (x, -15, 15), (y, -15, 15))
